# %%
import pandas as pd

# Example: however you already read your chat
df_raw = pd.read_csv("_chat.txt", header=None, names=["raw"])
print(df_raw.head(10))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/c0/mzdr1qtx22s4c_pjntcjlgm80000gn/T/ipykernel_2187/3742775749.py in <module>
#       2
#       3 # Example: however you already read your chat
# ----> 4 df_raw = pd.read_csv("_chat.txt", header=None, names=["raw"])
#       5 print(df_raw.head(10))
#       6
#
# ~/miniconda3/envs/myenv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
